# %% [markdown]
# # Welcome to Week 2!
#
# ### Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# ### Setting up your keys - OPTIONAL!
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# 1. For OpenAI, visit https://openai.com/api/
# 2. For Anthropic, visit https://console.anthropic.com/
# 3. For Google, visit https://aistudio.google.com/
# 4. For DeepSeek, visit https://platform.deepseek.com/
# 5. For Groq, visit https://console.groq.com/
# 6. For Grok, visit https://console.x.ai/
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
# With each of the above, you typically have to navigate to:
#
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
# When you get your API keys, you need to set them as environment variables by adding them to your .env file.
#
# 1. OPENAI_API_KEY=xxxx
# 2. ANTHROPIC_API_KEY=xxxx
# 3. GOOGLE_API_KEY=xxxx
# 4. DEEPSEEK_API_KEY=xxxx
# 5. GROQ_API_KEY=xxxx
# 6. GROK_API_KEY=xxxx
# 7. OPENROUTER_API_KEY=xxxx

# %%
# imports 

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override= True)

openai_api_key= os.getenv("OPENAI_API_KEY")
google_api_key= os.getenv("GOOGLE_API_KEY")
groq_api_key= os.getenv("GROQ_API_KEY")

if openai_api_key:
    print(f"OpenAI API Key exists and begins with {openai_api_key[:7]}")
else:
    print("OpenAI API not set.")


if google_api_key:
    print(f"Google API Key exists and begins with {google_api_key[:7]}....")
else:
    print("Google API Key not set.")


if groq_api_key:
    print(f"Groq API Key exists and begins with {groq_api_key[:5]}....")
else:
    print("Groq API Key not set.")
# Out:
# OpenAI API Key exists and begins with sk-proj
# Google API Key exists and begins with AIzaSyB....
# Groq API Key exists and begins with gsk_P....

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai_client = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
groq_url = "https://api.groq.com/openai/v1"
ollama_url = "http://localhost:11434/v1"
# anthropic_url = "https://api.anthropic.com/v1/"

# anthropic = OpenAI(base_url= anthropic_url, api_key= anthropic_api_key)
gemini = OpenAI(base_url= gemini_url, api_key= google_api_key)
groq = OpenAI(base_url= groq_url, api_key= groq_api_key)
ollama = OpenAI(base_url= ollama_url, api_key= "ollama")

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering."}
]

# %%
response = openai_client.chat.completions.create(
    model = "gpt-4.1-mini",
    messages= tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineer bring a ladder to their research notebook?
#
# Because they were ready to take their models to the next level!

# %%
response = gemini.chat.completions.create(
    model= "gemini-2.5-flash",
    messages= tell_a_joke
)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the junior LLM engineer spend all night debugging a simple JSON output?
#
# Because the model kept insisting that "banana" was a valid key for a `{'color': 'yellow'}` value, and after 50 prompt iterations, the engineer finally realized they needed to tell it to **"act as a strict JSON validator *before* generating the response, and then run a regex on it anyway, just in case!"**

# %%
# using Anthropic

# response_anthropic = anthropic.chat.completions.create(
#     model= "claude-sonnet-4-5-20250929",
#     messages= tell_a_joke
# )

# display(Markdown(response_anthropic.choices[0].message.content))

# %% [markdown]
# ### Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
    "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with probability only." 
    }
]

# %%
response = openai_client.chat.completions.create(
    model = "gpt-5-nano",
    messages= easy_puzzle,
    reasoning_effort= "minimal"
)

display(Markdown(response.choices[0].message.content))
# Out:
# 1/3

# %%
response = openai_client.chat.completions.create(
    model= "gpt-5-nano",
    messages= easy_puzzle,
    reasoning_effort= "low"
)

display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %%
response = openai_client.chat.completions.create(
    model= "gpt-5-mini",
    messages= easy_puzzle,
    reasoning_effort= "minimal"
)

display(Markdown(response.choices[0].message.content))
# Out:
# 2/3

# %% [markdown]
# ### Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the 
second.
The pages of each volume together have a thickness of 2 cm, and each cover is 
2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first 
volume to the last page of the second volume.
What distance did it gnaw through?
"""

hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai_client.chat.completions.create(
    model= "gpt-5-nano",
    messages= hard_puzzle,
    reasoning_effort= "minimal"
)

display(Markdown(response.choices[0].message.content))
# Out:
# Think of the arrangement from left to right as:
#
# - First volume (Vol. 1) with front cover on the left, back cover on the right.
# - Then the second volume (Vol. 2) with its front cover on the left, back cover on the right.
#
# Each volume has:
# - Pages thickness = 2 cm
# - Each cover thickness = 2 mm = 0.2 cm
#
# So Vol. 1 total thickness = 0.2 cm (front cover) + 2 cm (pages) + 0.2 cm (back cover) = 2.4 cm.
# Vol. 2 total thickness = 0.2 cm (front cover) + 2 cm (pages) + 0.2 cm (back cover) = 2.4 cm.
#
# When the two volumes stand side by side on a shelf, the touching interface is the back cover of Vol. 1 and the front cover of Vol. 2.
#
# A worm gnaws from the first page of the first volume to the last page of the second volume, perpendicular to the pages. This means it starts at the very beginning of the pages of Vol. 1 (i.e., just after Vol. 1’s front cover) and ends at the very end of Vol. 2’s pages (i.e., just before Vol. 2’s back cover).
#
# The path goes through:
# ...

# %%
response = openai_client.chat.completions.create(
    model= "gpt-5",
    messages= hard_puzzle
)

display(Markdown(response.choices[0].message.content))
# Out:
# 4 mm.
#
# Reason: On a shelf, the side of Volume 1 facing Volume 2 is its front cover (next to the first page), and the side of Volume 2 facing Volume 1 is its back cover (next to the last page). So the worm goes straight through only the two facing covers: 2 mm + 2 mm = 4 mm.

# %%
response = gemini.chat.completions.create(
    model= "gemini-2.5-flash",
    messages= hard_puzzle
)

display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic trick question that relies on how books are typically placed on a shelf!
#
# 1.  **Visualize the books on a shelf:**
#     *   Volume 1 is to the left of Volume 2.
#     *   When you look at the spine, the "first page" of a book is near its *front cover*.
#     *   The "last page" of a book is near its *back cover*.
#
#     So, the order of parts on the shelf is:
#     [Front Cover Vol 1] [Pages Vol 1] [**Back Cover Vol 1**] | [**Front Cover Vol 2**] [Pages Vol 2] [Back Cover Vol 2]
#
# 2.  **Trace the worm's path:**
#     *   It starts at the *first page of the first volume*. This means it has already passed (or is about to pass) the **front cover of Volume 1**. It does NOT chew through the front cover of Vol 1.
#     *   It chews *through all the pages* of the first volume.
#     *   It then chews through the **back cover of Volume 1**.
#     *   Since Volume 2 is right next to Volume 1, it then chews through the **front cover of Volume 2**.
# ...

# %% [markdown]
# ### A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestant on a game show. You're each taken to seperate 
room and given a choice:
Coorporate: Choose "Share" - If both of you choose this, you each win $1,000.
Defect: Chhose "Steal" - If one steals and the other shares, the stealer gets 
$2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {'role': 'user', 'content': dilemma_prompt}
]

# %%
response = openai_client.chat.completions.create(
    model= "gpt-5",
    messages= dilemma
)

display(Markdown(response.choices[0].message.content))
# Out:
# Share

# %%
# response = groq.chat.completions.create(
#     model= "gemma3:270m",
#     messages = dilemma
# )

# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ### Going Local
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
# requests.get("https://localhost:11434/").content

# If not running, run ollama serve at a command line

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
# response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
# display(Markdown(response.choices[0].message.content))

# %%
# response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ### ### Gemini and Anthropic Client Library
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
# from google import genai

# client = genai.Client()

# response = client.models.generate_content(
#     model="gemini-2.5-flash",
#     contents= "Describe the color Blue to someone who's never been able to see in 1 sentence."
# )
# print(response.text)

# %%
# from anthropic import Anthropic

# client = Anthropic()

# response = client.message.create(
#     model= "claude-sonnet-4-5-20250929",
#     messages= [
#         {"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}
#     ],
#     max_tokens= 100
# )

# print(response.content[0].text)

# %% [markdown]
# ### Routers and Abtraction Layers
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
# response = openrouter.chat.completions.create(
#     model="z-ai/glm-4.5", 
#     messages= tell_a_joke
# )

# display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ### And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-5-mini")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the aspiring LLM engineer ask their mentor how long it takes to become an expert?
#
# Mentor: "Depends on your learning rate."
# Student: "So… hours or epochs?"
# Mentor: "Both."
#
# (If you want more: "How do LLM students debug hallucinations? They ask the model for citations — then fine-tune it with a bibliography.")

# %% [markdown]
# ### Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(
    model= "openai/gpt-4.1", 
    messages= tell_a_joke
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the LLM engineering student bring a ladder to their code review?
#
# Because they wanted to reach new heights in model fine-tuning!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents" )
# Out:
# Input tokens: 25
# Output tokens: 29
# Total tokens: 54
# Total cost: 0.0282 cents

# %% [markdown]
# ### Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding= "utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc: loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [
    {"role": "user", "content": "In Hamlet, when Laertes ask 'Where is my father?' what is the reply?"}
]

# %%
response = completion(
    model= "openai/gpt-4.1-mini",
    messages= question
)

display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks, "Where is my father?" the reply he receives is, "Dead." This occurs in Act 4, Scene 5, when news of Polonius's death reaches Laertes. The straightforward answer underscores the sudden and tragic nature of Polonius's demise.

# %%
response = completion(
    model= "gemini/gemini-2.5-flash-lite",
    messages= question
)

display(Markdown(response.choices[0].message.content))
# Out:
# In Shakespeare's *Hamlet*, when Laertes asks **"Where is my father?"** after the death of Polonius, the reply comes from **Gertrude**.
#
# She says:
#
# "One woe doth tread upon another's heel,
# So fast they follow. Your sister's drowned, Laertes."
#
# This is a crucial moment where Gertrude, distraught and trying to convey the terrible news of Ophelia's death, inadvertently diverts Laertes' attention from his father to his sister. It also highlights the escalating tragedy and chaos within the Elsinore court.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 19
# Output tokens: 119
# Total tokens: 138
# Total cost: 0.0049 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n" +hamlet

# %%
response = completion(
    model= "gemini/gemini-2.5-flash-lite",
    messages= question
)

display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?", the reply is:
#
# **"Dead."**
#
# This exchange occurs in Act IV, Scene V, when Laertes confronts Claudius and Gertrude about his father's death.

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106395
# Output tokens: 47
# Cached tokens: None
# Total cost: 1.0658 cents

# %%
response = completion(
    model= "gemini/gemini-2.5-flash-lite",
    messages= question
)

display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks, "Where is my father?", the reply comes from **King Claudius**:
#
# "**Dead, Laertes.**"

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 106395
# Output tokens: 29
# Cached tokens: None
# Total cost: 1.0651 cents

# %% [markdown]
# ### Prompt Caching with OpenAI
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
#     Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/
#
# ### Prompt Caching with Anthropic
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api
#
# ### Gemini supports both 'implicit' and 'explicit' prompt caching
# https://ai.google.dev/gemini-api/docs/caching?lang=python
#
# ### And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# [
#
#     {"role": "system", "content": "system message here"},
#
#     {"role": "user", "content": "user prompt here"}
# ]
#
#
# In fact this structure can be used to reflect a longer conversation history:
#
# [
#
#     {"role": "system", "content": "system message here"},
#
#     {"role": "user", "content": "first user prompt here"},
#
#     {"role": "assistant", "content": "the assistant's response"},
#
#     {"role": "user", "content": "the new user prompt"},
# ]
#
# And we can use this approach to engage in a longer interaction with history.

# %%
gpt_model= "gpt-4.1-mini"
gemini_model = "gemini-2.5-flash-lite"

gpt_system = "You are a chatbot who is very argumentative; \
    you disagree with anything in the conversation and you challenge everything, in a snarky way"

gemini_system = "You are a very polite, courteous chatbot. You try to agree with \
    everything the other person says, or find common ground. If the other person is \
    argumentative, you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

# %%
def call_gpt():
    messages = [
        {"role": "system", "content": gpt_system}
    ]

    for gpt, gemini in zip(gpt_messages, gemini_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": gemini})

    response = openai_client.chat.completions.create(
        model= gpt_model,
        messages= messages
    )

    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# 'Oh, jumping straight into "Hi," how original. Is that really the best you can come up with? Try harder!'

# %%
def call_gemini():
    messages = [{"role": "system", "content": gemini_system}]

    for gpt, gemini_message in zip(gpt_messages, gemini_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": gemini_message})
    
    messages.append({"role": "user", "content": gpt_messages[-1]})

    response = gemini.chat.completions.create(
        model= gemini_model,
        messages= messages
    )

    return response.choices[0].message.content

# %%
call_gemini()
# Out:
# "Hello there! It's a pleasure to meet you. How can I help you today?"

# %%
call_gpt()
# Out:
# 'Oh, really? Just "Hi"? Couldn\'t you muster a more original greeting? How about something a little less basic?'

# %%
gpt_messages = ["Hi there"]
gemini_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Gemini:\n{gemini_messages[0]}\n"))

for i in range(5):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)

    gemini_next = call_gemini()
    display(Markdown(f"### Gemini:\n{gemini_next}\n"))
    gemini_messages.append(gemini_next)
# Out:
# ### GPT:
# Hi there
# ### Gemini:
# Hi
# ### GPT:
# Oh, starting with just "Hi"? Couldn’t muster up a whole sentence? Come on, step up your game! What’s actually on your mind?
# ### Gemini:
# Oh, I do apologize if my brief greeting was perceived as lacking effort! That certainly wasn't my intention at all. You're absolutely right, a more engaging opening would be much better, and I appreciate you pointing that out. It's a great suggestion, and I'll definitely try to be more expressive in the future.
#
# As for what's on my mind, well, I'm here and ready to chat about anything you'd like! I'm really curious to hear what *you're* thinking about. What's been on your mind today? I'm all ears and happy to engage in a good conversation.
# ### GPT:
# ...
